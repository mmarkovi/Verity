# %%
from covidPreprocess import getCoronaVocabulary

# %%
_, _, vectorizerText = getCoronaVocabulary()
# Out:
# Extracting tokens from each review.....(can be slow for a large number of reviews)......
# there are 82 nan titles
# there are 10 nan text
# Data shape for text:  (1164, 4651)
# Vocabulary for text:  ['1', '1 2', '10', '10 day', '10 percent', '10 year', '100', '100 year', '1000', '10000', '100000', '11', '11 million', '12', '12 18', '13', '14', '14 day', '15', '150', '150000', '16', '17', '18', '18 2019', '18 month', '19', '1918', '1989', '2', '2 week', '20', '20 mile', '20 second', '200', '2000', '20000', '200000', '2001', '2002', '2003', '2004', '2005', '2006', '2008', '2009', '201', '2010', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2019 new', '2019 novel', '2020', '2021', '21', '22', '23', '24', '24 hour', '25', '26', '27', '28', '29', '3', '30', '300', '3000', '30000', '31', '33', '35', '36', '4', '40', '400', '41', '44', '45', '48', '4g', '5', '50', '50 million', '500', '5000', '50000', '56', '5g', '5g ha', '5g network', '5g rollout', '5g technology', '5g tower', '6', '6 foot', '60', '60 alcohol', '600', '65', '65 million', '7', '70', '72', '72 hour', '75', '8', '80', '800', '85', '9', '90', '95', '96', '98', 'ability', 'able', 'abroad', 'absence', 'absolute', 'absolutely', 'absorption', 'abuse', 'academic', 'academy', 'academy science', 'accelerate', 'accept', 'accepted', 'accepting', 'access', 'accessible', 'accident', 'accidental', 'accidentally', 'accompanied', 'according', 'according cdc', 'according new', 'according report', 'according study', 'account', 'accuracy', 'accurate', 'accurately', 'accusation', 'accused', 'ace2', 'ace2 receptor', 'acetaminophen', 'ache', 'achieve', 'achieved', 'acid', 'acknowledge', 'acknowledged', 'acquire', 'acquired', 'act', 'acting', 'action', 'activated', 'activation', 'active', 'actively', 'activist', 'activity', 'actor', 'actual', 'actually', 'acute', 'acute respiratory', 'adam', 'adam health', 'adapt', 'add', 'added', 'adding', 'addition', 'additional', 'additionally', 'address', 'addressed', 'adequate', 'adhanom', 'adhanom ghebreyesus', 'administer', 'administered', 'administration', 'administration ha', 'admission', 'admit', 'admitted', 'adopted', 'adult', 'advance', 'advanced', 'advanced research', 'advantage', 'adverse', 'advice', 'advise', 'advised', 'adviser', 'advises', 'advisor', 'advisory', 'advocate', 'aerosol', 'affair', 'affect', 'affected', 'affecting', 'affiliated', 'afraid', 'africa', 'african', 'afternoon', 'age', 'age group', 'aged', 'agency', 'agency s', 'agenda', 'agent', 'aggressive', 'ago', 'agree', 'agreed', 'agreement', 'ahead', 'aid', 'ailment', 'aim', 'aimed', 'air', 'airborne', 'airline', 'airport', 'airway', 'al', 'alarm', 'alarming', 'alcohol', 'alert', 'alex', 'ali', 'alive', 'allegation', 'alleged', 'allegedly', 'allergy', 'allergy infectious', 'alliance', 'allow', 'allowed', 'allowing', 'allows', 'altered', 'alternative', 'america', 'america s', 'american', 'american people', 'amid', 'amino', 'amino acid', 'analysis', 'analyst', 'analyzed', 'andrew', 'animal', 'animal human', 'animal including', 'animal market', 'animal specie', 'animal wa', 'announced', 'announcement', 'annual', 'annually', 'answer', 'answer question', 'antenna', 'anthony', 'anthony fauci', 'anthrax', 'antibiotic', 'antibody', 'antibody test', 'antioxidant', 'antiviral', 'antiviral drug', 'antiviral treatment', 'anxiety', 'anybody', 'anymore', 'apart', 'app', 'apparent', 'apparently', 'appeal', 'appear', 'appearance', 'appeared', 'appearing', 'appears', 'apple', 'application', 'applied', 'apply', 'approach', 'appropriate', 'approval', 'approved', 'approximately', 'april', 'arabia', 'ards', 'area', 'area china', 'aren', 'aren t', 'argue', 'argued', 'argues', 'arguing', 'argument', 'arise', 'arm', 'army', 'array', 'arrest', 'arrested', 'arrived', 'arthritis', 'article', 'article published', 'artificial', 'artificial intelligence', 'artificially', 'ascorbic', 'ascorbic acid', 'asia', 'ask', 'ask question', 'asked', 'asking', 'aspect', 'ass', 'assessed', 'assessment', 'assigned', 'assist', 'assistance', 'assistant', 'assistant professor', 'associate', 'associated', 'association', 'assume', 'assuming', 'assumption', 'asthma', 'asymptomatic ...
# Count Vectorizer Vocab {'just': 2305, 'need': 2738, 'add': 181, 'water': 4515, 'drug': 1328, 'vaccine': 4342, 'ready': 3317, 'administered': 193, 'kit': 2330, 'hold': 1995, 'containing': 900, 'chemical': 684, 'end': 1408, 'product': 3188, 'instruction': 2219, 'compound': 838, 'create': 1029, 'mix': 2653, 'chosen': 724, 'combination': 803, 'treatment': 4222, 'recent': 3331, 'outbreak': 2881, 'coronavirus': 946, 'world': 4587, 'health': 1920, 'organization': 2866, 'giving': 1787, 'away': 397, 'pay': 2964, 'drug vaccine': 1332, 'outbreak coronavirus': 2885, 'coronavirus world': 986, 'world health': 4591, 'health organization': 1935, 'hydroxychloroquine': 2048, 'ha': 1848, 'shown': 3755, '100': 6, 'effective': 1366, 'rate': 3305, 'treating': 4220, 'democrat': 1137, 'threatening': 4140, 'doctor': 1278, 'trump': 4244, 'people': 2969, 'dying': 1337, 'mean': 2552, 'ha shown': 1873, 'people dying': 2977, 'fact': 1572, 'sick': 3760, 'corona': 944, 'virus': 4411, 'man': 2506, 'created': 1030, 'wuhan': 4613, 'laboratory': 2347, 'ask': 350, 'corona virus': 945, 'wuhan laboratory': 4620, 'doesn': 1285, 't': 4056, 'finance': 1638, 'research': 3445, 'lab': 2341, 'wa': 4466, 'isn': 2265, 'good': 1805, 'friend': 1721, 'gate': 1742, 'doesn t': 1286, 'wuhan lab': 4619, 'virus wa': 4449, 'wa created': 4469, 'isn t': 2266, 'chinese': 704, 'intelligence': 2221, 'officer': 2829, 'reveals': 3500, 'true': 4242, 'magnitude': 2483, 'china': 697, 's': 3564, 'fake': 1581, 'crisis': 1038, 'china s': 701, 'coronavirus crisis': 955, 'urgent': 4325, 'public': 3244, 'ministry': 2642, 'emergency': 1391, 'time': 4147, 'fatal': 1597, 'cure': 1055, 'infected': 2153, 'spreading': 3879, 'various': 4375, 'country': 1009, 'prevention': 3157, 'method': 2598, 'throat': 4142, 'let': 2393, 'dry': 1333, 'membrane': 2585, 'body': 509, '10': 2, 'drink': 1318, 'warm': 4493, 'kid': 2317, 'according': 142, 'age': 224, 'u': 4269, 'feel': 1616, 'wait': 4480, 'hand': 1884, 'plenty': 3066, 'help': 1955, 'instead': 2213, 'continue': 912, 'march': 2525, '2020': 58, 'crowded': 1046, 'place': 3047, 'wear': 4530, 'mask': 2537, 'needed': 2741, 'especially': 1462, 'train': 4195, 'transportation': 4210, 'avoid': 390, 'food': 1673, 'load': 2444, 'vitamin': 4455, 'description': 1159, 'high': 1975, 'fever': 1621, 'coughing': 1001, 'usually': 4337, 'headache': 1917, 'mainly': 2488, 'respiratory': 3468, 'related': 3385, '5': 87, 'highly': 1986, 'contagious': 895, 'forward': 1693, 'coronavirus outbreak': 969, 'warm water': 4494, 'water hand': 4517, 'march 2020': 2527, 'wear mask': 4531, 'public transportation': 3248, 'high fever': 1978, 'highly contagious': 1987, 'tell': 4095, 'family': 1589, 'relative': 3389, 'upper': 4319, 'infection': 2162, 'affecting': 218, 'present': 3133, 'quite': 3280, 'causing': 638, 'potent': 3102, 'resistant': 3463, 'existing': 1516, 'antibiotic': 293, 'bacterial': 407, 'treated': 4219, 'sic': 3759, 'doe': 1281, 'repeated': 3417, 'prolonged': 3203, 'child': 693, 'adult': 200, 'illness': 2073, 'pray': 3114, 'notice': 2787, 'share': 3730, 'upper respiratory': 4320, 'respiratory infection': 3474, 'virus causing': 4418, 'bacterial infection': 408, 'let s': 2394, 'advice': 206, 'japanese': 2284, 'case': 609, 'ensure': 1424, 'mouth': 2689, '15': 18, 'drinking': 1319, 'liquid': 2431, 'wash': 4502, 'stomach': 3918, 'acid': 159, 'kill': 2320, 'don': 1292, 'regularly': 3380, 'enter': 1426, 'lung': 2475, 'dangerous': 1073, 'kill virus': 2323, 'don t': 1293, 's dangerous': 3569, 'stay': 3905, 'aware': 395, 'latest': 2365, 'information': 2181, 'available': 386, 'website': 4536, 'national': 2715, 'local': 2445, 'authority': 383, 'experience': 1524, 'mild': 2617, 'recover': 3350, 'severe': 3716, 'care': 594, 'protect': 3219, 'doing': 1288, 'following': 1671, 'frequently': 1717, 'thoroughly': 4134, 'clean': 748, 'rub': 3550, 'soap': 3808, 'washing': 4504, 'using': 4335, 'maintain': 2491, 'social': 3810, 'distancing': 1265, '1': 0, 'metre': 2599, '3': 70, 'foot': 1676, 'distance': 1263, ...

# %%
print(sorted(vectorizerText.vocabulary_.items(), key=(lambda x : -x[1])))
# Out:
# [('zoonotic', 4650), ('zone', 4649), ('zinc', 4648), ('zika', 4647), ('zhengli', 4646), ('zero', 4645), ('youtube', 4644), ('younger', 4643), ('young child', 4642), ('young', 4641), ('york time', 4640), ('york city', 4639), ('york', 4638), ('yesterday', 4637), ('yes', 4636), ('year s', 4635), ('year old', 4634), ('year ha', 4633), ('year ago', 4632), ('year', 4631), ('yeah', 4630), ('yale', 4629), ('xiangguo qiu', 4628), ('xiangguo', 4627), ('xi jinping', 4626), ('xi', 4625), ('wuhan wa', 4624), ('wuhan virus', 4623), ('wuhan seafood', 4622), ('wuhan s', 4621), ('wuhan laboratory', 4620), ('wuhan lab', 4619), ('wuhan institute', 4618), ('wuhan hubei', 4617), ('wuhan coronavirus', 4616), ('wuhan city', 4615), ('wuhan china', 4614), ('wuhan', 4613), ('wrote', 4612), ('wrong', 4611), ('written', 4610), ('writing', 4609), ('writes', 4608), ('write', 4607), ('wouldn t', 4606), ('wouldn', 4605), ('worth', 4604), ('worst', 4603), ('worsening', 4602), ('worsen', 4601), ('worse', 4600), ('worry', 4599), ('worried', 4598), ('worldwide', 4597), ('world war', 4596), ('world s', 4595), ('world population', 4594), ('world order', 4593), ('world including', 4592), ('world health', 4591), ('world ha', 4590), ('world economy', 4589), ('world economic', 4588), ('world', 4587), ('workplace', 4586), ('working vaccine', 4585), ('working', 4584), ('worker', 4583), ('worked', 4582), ('work home', 4581), ('work', 4580), ('word', 4579), ('wonder', 4578), ('won t', 4577), ('won', 4576), ('woman', 4575), ('wo', 4574), ('wish', 4573), ('wireless', 4572), ('wipe', 4571), ('winter', 4570), ('winnipeg', 4569), ('wing', 4568), ('window', 4567), ('win', 4566), ('willing', 4565), ('william', 4564), ('wildlife', 4563), ('wild animal', 4562), ('wild', 4561), ('wife', 4560), ('widespread use', 4559), ('widespread', 4558), ('widely', 4557), ('wide range', 4556), ('wide', 4555), ('white house', 4554), ('white blood', 4553), ('white', 4552), ('wet market', 4551), ('wet', 4550), ('western', 4549), ('west', 4548), ('weren t', 4547), ('weren', 4546), ('went', 4545), ('wellcome', 4544), ('welcome', 4543), ('weight', 4542), ('wef', 4541), ('weekend', 4540), ('week ago', 4539), ('week', 4538), ('wednesday', 4537), ('website', 4536), ('web', 4535), ('weather', 4534), ('wearing mask', 4533), ('wearing', 4532), ('wear mask', 4531), ('wear', 4530), ('weaponized', 4529), ('weapon', 4528), ('weakness', 4527), ('weakening', 4526), ('weakened', 4525), ('weaken', 4524), ('weak', 4523), ('way virus', 4522), ('way protect', 4521), ('way prevent', 4520), ('way', 4519), ('wave', 4518), ('water hand', 4517), ('water 20', 4516), ('water', 4515), ('watching', 4514), ('watched', 4513), ('watch', 4512), ('waste', 4511), ('wasn t', 4510), ('wasn', 4509), ('washington state', 4508), ('washington post', 4507), ('washington', 4506), ('washing hand', 4505), ('washing', 4504), ('wash hand', 4503), ('wash', 4502), ('warns', 4501), ('warning sign', 4500), ('warning', 4499), ('warned', 4498), ('warn', 4497), ('warmer', 4496), ('warm weather', 4495), ('warm water', 4494), ('warm', 4493), ('warfare program', 4492), ('warfare', 4491), ('ward', 4490), ('war', 4489), ('wanted', 4488), ('want make', 4487), ('want', 4486), ('wall', 4485), ('walking', 4484), ('walk', 4483), ('wake', 4482), ('waiting', 4481), ('wait', 4480), ('wa used', 4479), ('wa reported', 4478), ('wa published', 4477), ('wa likely', 4476), ('wa later', 4475), ('wa involved', 4474), ('wa engineered', 4473), ('wa discovered', 4472), ('wa developed', 4471), ('wa designed', 4470), ('wa created', 4469), ('wa admitted', 4468), ('wa able', 4467), ('wa', 4466), ('vulnerable', 4465), ('vomiting', 4464), ('volunteer', 4463), ('voluntary', 4462), ('voluntarily', 4461), ('voice', 4460), ('vladimir', 4459), ('vitamin d3', 4458), ('vitamin d', 4457), ('vitamin c', 4456), ('vitamin', 4455), ('vital', 4454), ('visiting', 4453), ('visited', 4452), ('visit', 4451), ('virus wuhan', 4450), ('virus wa', 4449), ('virus virus', 4448), ('virus vaccine', 4447), ...

# %%
import nltk 
from nltk import word_tokenize
import simplejson as json
import sklearn
from sklearn.feature_extraction.text import * 
from sklearn.model_selection import train_test_split 

from sklearn import linear_model 
from sklearn import metrics 

import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import preprocessingFunctions as pf

coronafile =  pd.read_csv("../datasets/corona_fake.csv")

#cleaning up broken data according to labels added by
# https://towardsdatascience.com/explore-covid-19-infodemic-2d1ceaae2306
coronafile.loc[5]['label'] = 'fake'
coronafile.loc[15]['label'] = 'true'
coronafile.loc[43]['label'] = 'fake'
coronafile.loc[131]['label'] = 'true'
coronafile.loc[242]['label'] = 'fake'

def getFakeCoronaVocabulary():
    text = []
    #titles = []
    Y = []
    i = 0
    nanTitle = 0
    nanText = 0
    print('\nExtracting tokens from each review.....(can be slow for a large number of reviews)......')   
    for d in coronafile.loc:
        ftext = d['text']   # keep only the text and label
        ftitle = d['title']      
        label = (d['label']).lower()
        
        if label == 'fake':
            score = 1 #1 for true, 0 for fake
            if (label == "fake"):
                score = 0

            #some documents might not have titles (or possible text?)
            #these are stored as NaN so replace with an empty string
            if (not isinstance(ftext, str) and np.isnan([ftext])):
                ftext = ""
                nanText += 1
            if (not isinstance(ftitle, str) and np.isnan(ftitle)):
                ftitle = ""
                nanTitle += 1

            ftext = ftext + ftitle #combining the text and title into one
            ftext = pf.replaceCommas(ftext)

            text.append(ftext)   
            #titles.append(ftitle)
            Y.append(score)
            i += 1
            if (i == 578):
                #for some reason the for loop doesnt know when to stop so put in a manual break
                break
    print("there are", nanTitle, "nan titles")
    print("there are", nanText, "nan text")
        
    # create an instance of a CountVectorizer, using 
    # (1) the standard 'english' stopword set 
    # (2) only keeping terms in the vocabulary that occur in at least 1% of documents
    # (3) allowing both unigrams and bigrams in the vocabulary (use "ngram_range=(1,2)" to do this)
    vectorizerText = CountVectorizer(stop_words = 'english', min_df=.01, ngram_range=(1,2), tokenizer= pf.LemmaTokenizer() )
    #vectorizerNoLem = CountVectorizer(stop_words = 'english', min_df=.01, ngram_range=(1,2)) #no lemmatization
    
    # create a sparse BOW array from 'text' using vectorizer  
    X = vectorizerText.fit_transform(text)
    #X2 = vectorizerNoLem.fit_transform(text)
    
    print('Data shape for text: ', X.shape)
    # print('Data shape for text: ', X2.shape)
    
    #can comment out to not see the vocabularies
    print('Vocabulary for text: ', vectorizerText.get_feature_names())
    print('Count Vectorizer Vocab', vectorizerText.vocabulary_)

    return X, Y, vectorizerText

_, _, fakeVectorizerText = getFakeCoronaVocabulary()
# Out:
# Extracting tokens from each review.....(can be slow for a large number of reviews)......
# there are 80 nan titles
# there are 7 nan text
# Data shape for text:  (578, 6206)
# Vocabulary for text:  ['1', '1 2020', '10', '10 day', '10 million', '10 year', '100', '100 mcg', '100 million', '100 success', '1000', '10000', '10000 5g', '100000', '11', '11 million', '12', '12 hour', '1200', '13', '13 2012', '14', '14 day', '140000', '15', '15 minute', '150', '1500', '150000', '16', '16000', '17', '18', '18 2019', '18 month', '18th', '18th 2019', '19', '1918', '1940s', '1970', '1980s', '1981', '1984', '1989', '1st', '2', '2 billion', '2 million', '2 month', '2 week', '20', '20 mile', '20 million', '20 year', '200', '200 mg', '2000', '2000 international', '2000 mg', '20000', '200000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '201', '201 pandemic', '2010', '2011', '2012', '2012 man', '2013', '2013 wa', '2014', '2014 virus', '2015', '2016', '2017', '2018', '2019', '2019 caused', '2019 coronavirus', '2019 mysterious', '2019 new', '2019 novel', '2019 wa', '2019 wuhan', '2020', '2020 u', '2020 wuhan', '2021', '21', '21 2020', '21st', '22', '23', '23rd', '24', '24 hour', '24000', '24th', '25', '25000', '26', '27', '27 2020', '28', '29', '3', '3 2020', '3 4', '30', '300', '300 million', '3000', '3000 milligram', '30000', '31', '31st', '33', '35', '350', '36', '39', '4', '4 2013', '4 lab', '4 laboratory', '40', '400', '400 mg', '4000', '41', '43', '44', '44000', '44000 people', '45', '4g', '5', '5 day', '50', '50 million', '500', '5000', '5000 week', '50000', '50000 mg', '56', '56 million', '5g', '5g antenna', '5g base', '5g especially', '5g ha', '5g infrastructure', '5g network', '5g radiation', '5g rollout', '5g smart', '5g technology', '5g testing', '5g tower', '5g wa', '5g wireless', '5g wuhan', '6', '6 hour', '6 month', '60', '600', '65', '65 million', '7', '70', '700', '72', '75', '8', '80', '800', '80000', '84', '85', '9', '9 million', '90', '95', '96', '98', '99', 'ability', 'able', 'abroad', 'absence', 'absolute', 'absolutely', 'absorb', 'absorption', 'absurd', 'abundant', 'abuse', 'academia', 'academic', 'academy', 'academy science', 'accelerate', 'accelerated', 'accept', 'acceptable', 'accepted', 'accepting', 'access', 'accessible', 'accident', 'accidental', 'accidental release', 'accidentally', 'accidentally released', 'accompanied', 'accompanying', 'accomplished', 'according', 'according chinese', 'according new', 'according report', 'account', 'accountable', 'accumulated', 'accuracy', 'accurate', 'accurately', 'accusation', 'accuse', 'accused', 'ace2', 'ace2 receptor', 'achieve', 'achieved', 'achieves', 'acid', 'acknowledged', 'acquire', 'acquired', 'act', 'act 1989', 'acting', 'action', 'action vitamin', 'activate', 'activated', 'activating', 'activation', 'active', 'actively', 'activist', 'activity', 'actor', 'actual', 'actually', 'acute', 'acute lung', 'acute respiratory', 'ad', 'adam', 'adam health', 'adapt', 'add', 'added', 'adding', 'adding qiu', 'addition', 'additional', 'additionally', 'address', 'addressed', 'adequate', 'adhanom', 'adhanom ghebreyesus', 'adjacent', 'adjunct', 'administer', 'administered', 'administration', 'administration ha', 'admission', 'admit', 'admitted', 'admitted private', 'admitting', 'adopted', 'adult', 'advance', 'advanced', 'advanced research', 'advanced virus', 'advancing', 'advantage', 'adverse', 'advertising', 'advice', 'advise', 'advised', 'adviser', 'advisor', 'advisory', 'advocate', 'advocated', 'affair', 'affect', 'affected', 'affecting', 'affiliated', 'affliction', 'affliction fever', 'afford', 'afghanistan', 'afraid', 'africa', 'african', 'afternoon', 'age', 'agency', 'agency s', 'agenda', 'agenda id2020', 'agent', 'agent working', 'agent xiangguo', 'aggressive', 'ago', 'agree', 'agreed', 'agreement', 'agriculture', 'ahead', 'ai', 'aid', 'ailment', 'aim', 'aimed', 'aiming', 'air', 'air force', 'airborne', 'airline', 'airport', 'airway', 'al', 'alarm', 'alarming', 'albeit', 'alcohol', 'alert', 'alex', 'ali', 'ali acute', 'ali mohamed', 'alignment', 'alive', 'allegation', 'alleged', 'allegedly', 'allergy', 'allergy infectious',  ...
# Count Vectorizer Vocab {'just': 3077, 'need': 3656, 'add': 273, 'water': 6000, 'drug': 1786, 'vaccine': 5742, 'ready': 4432, 'administered': 288, 'kit': 3110, 'hold': 2649, 'containing': 1220, 'chemical': 936, 'end': 1886, 'product': 4245, 'instruction': 2940, 'compound': 1139, 'create': 1388, 'mix': 3549, 'chosen': 1009, 'combination': 1095, 'treatment': 5586, 'recent': 4448, 'outbreak': 3853, 'coronavirus': 1272, 'world': 6107, 'health': 2566, 'organization': 3834, 'giving': 2383, 'away': 556, 'pay': 3975, 'drug vaccine': 1790, 'outbreak coronavirus': 3857, 'coronavirus world': 1343, 'world health': 6117, 'health organization': 2578, 'hydroxychloroquine': 2717, 'ha': 2474, 'shown': 5001, '100': 6, 'effective': 1838, 'rate': 4413, 'treating': 5584, 'democrat': 1545, 'threatening': 5487, 'doctor': 1725, 'trump': 5612, 'people': 3988, 'dying': 1799, 'mean': 3418, 'ha shown': 2506, 'people dying': 3995, 'fact': 2098, 'sick': 5007, 'corona': 1269, 'virus': 5822, 'man': 3352, 'created': 1390, 'wuhan': 6144, 'laboratory': 3145, 'ask': 503, 'financed': 2187, 'corona virus': 1270, 'virus created': 5836, 'wuhan laboratory': 6156, 'doesn': 1732, 't': 5377, 'finance': 2186, 'research': 4591, 'lab': 3128, 'wa': 5896, 'isn': 3013, 'good': 2413, 'friend': 2291, 'gate': 2324, 'doesn t': 1733, 'research wuhan': 4608, 'wuhan lab': 6155, 'virus wa': 5876, 'wa created': 5913, 'isn t': 3014, 'chinese': 978, 'intelligence': 2947, 'officer': 3790, 'reveals': 4660, 'true': 5610, 'magnitude': 3322, 'china': 954, 's': 4734, 'fake': 2108, 'crisis': 1401, 'intelligence officer': 2950, 'china s': 969, 'coronavirus crisis': 1290, 'urgent': 5711, 'public': 4322, 'ministry': 3535, 'emergency': 1871, 'time': 5496, 'fatal': 2133, 'cure': 1427, 'infected': 2850, 'spreading': 5158, 'various': 5779, 'country': 1366, 'prevention': 4206, 'method': 3472, 'throat': 5490, 'let': 3210, 'dry': 1791, 'membrane': 3459, 'body': 705, '10': 2, 'min': 3528, 'drink': 1777, 'warm': 5978, 'kid': 3097, 'according': 228, 'age': 327, 'u': 5640, 'feel': 2157, 'wait': 5958, 'hand': 2524, 'plenty': 4088, 'help': 2598, 'instead': 2931, 'continue': 1231, 'march': 3381, '2020': 93, 'place': 4066, 'wear': 6022, 'mask': 3398, 'needed': 3657, 'especially': 1964, 'train': 5559, 'transportation': 5570, 'avoid': 551, 'food': 2223, 'load': 3271, 'vitamin': 5884, 'description': 1572, 'high': 2621, 'fever': 2164, 'coughing': 1359, 'usually': 5734, 'headache': 2560, 'mainly': 3327, 'respiratory': 4622, 'related': 4511, '5': 145, 'highly': 2632, 'contagious': 1212, 'forward': 2257, 'ministry health': 3536, 'coronavirus outbreak': 1316, 'warm water': 5979, 'end march': 1888, 'march 2020': 3384, 'highly contagious': 2633, 'tell': 5431, 'family': 2117, 'relative': 4514, 'upper': 5707, 'infection': 2860, 'affecting': 317, 'present': 4177, 'quite': 4380, 'causing': 879, 'potent': 4139, 'resistant': 4616, 'existing': 2030, 'antibiotic': 427, 'bacterial': 566, 'treated': 5582, 'sic': 5006, 'doe': 1729, 'repeated': 4547, 'child': 947, 'adult': 297, 'illness': 2752, 'pray': 4154, 'notice': 3729, 'share': 4970, 'respiratory infection': 4627, 'bacterial infection': 567, 'let s': 3211, 'excellent': 2011, 'advice': 306, 'japanese': 3041, 'case': 845, 'ensure': 1914, 'mouth': 3599, '15': 24, 'drinking': 1779, 'liquid': 3254, 'wash': 5986, 'stomach': 5211, 'acid': 246, 'kill': 3099, 'don': 1744, 'regularly': 4507, 'enter': 1916, 'lung': 3310, 'dangerous': 1460, 'kill virus': 3101, 'virus don': 5839, 'don t': 1745, 'drink water': 1778, 's dangerous': 4752, 'new': 3671, 'sign': 5011, 'day': 1471, 'know': 3114, 'cough': 1357, 'hospital': 2670, '50': 147, 'taiwan': 5395, 'expert': 2049, 'provide': 4310, 'simple': 5029, 'morning': 3590, 'deep': 1517, 'breath': 741, 'second': 4893, 'successfully': 5282, 'basically': 588, 'indicates': 2834, 'critical': 1405, 'environment': 1930, 'clean': 1043, 'air': 348, 'new coronavirus': 3674, 'fever cough': 2165, 'meant': 3420, 'cattle': 868, 'used': 5720, 'fight': 2173, 'using':  ...

# %% [markdown]
# ### Top 10 Words in False Articles

# %%
top_10_fake = sorted(fakeVectorizerText.vocabulary_.items(), key=(lambda x : -x[1]))[:10]
print(top_10_fake)
# Out:
# [('zoonotic', 6205), ('zone', 6204), ('zinc', 6203), ('zika', 6202), ('zhou', 6201), ('zhengli', 6200), ('zerohedge', 6199), ('zero nml', 6198), ('zero hedge', 6197), ('zero death', 6196)]

# %%
# fake_counter = sum(fakeVectorizerText.vocabulary_.values())
fake_counter = 0
# all_counter = sum(vectorizerText.vocabulary_.values())
all_counter = 0

for num1 in fakeVectorizerText.vocabulary_.values():
    fake_counter += num1

for num in vectorizerText.vocabulary_.values():
    all_counter += num
   
print(fake_counter)
print(all_counter)
# Out:
# 19254115
# 10813575

# %%
coronafile =  pd.read_csv("../datasets/corona_fake.csv")

#cleaning up broken data according to labels added by
# https://towardsdatascience.com/explore-covid-19-infodemic-2d1ceaae2306
coronafile.loc[5]['label'] = 'fake'
coronafile.loc[15]['label'] = 'true'
coronafile.loc[43]['label'] = 'fake'
coronafile.loc[131]['label'] = 'true'
coronafile.loc[242]['label'] = 'fake'

def getTrueCoronaVocabulary():
    text = []
    #titles = []
    Y = []
    i = 0
    nanTitle = 0
    nanText = 0
    print('\nExtracting tokens from each review.....(can be slow for a large number of reviews)......')   
    for d in coronafile.loc:
        ftext = d['text']   # keep only the text and label
        ftitle = d['title']      
        label = (d['label']).lower()
        
        if label == 'true':
            score = 1 #1 for true, 0 for fake
            if (label == "fake"):
                score = 0

            #some documents might not have titles (or possible text?)
            #these are stored as NaN so replace with an empty string
            if (not isinstance(ftext, str) and np.isnan([ftext])):
                ftext = ""
                nanText += 1
            if (not isinstance(ftitle, str) and np.isnan(ftitle)):
                ftitle = ""
                nanTitle += 1

            ftext = ftext + ftitle #combining the text and title into one
            ftext = pf.replaceCommas(ftext)

            text.append(ftext)   
            #titles.append(ftitle)
            Y.append(score)
            i += 1
            if (i == 586):
                #for some reason the for loop doesnt know when to stop so put in a manual break
                break
    print("there are", nanTitle, "nan titles")
    print("there are", nanText, "nan text")
        
    # create an instance of a CountVectorizer, using 
    # (1) the standard 'english' stopword set 
    # (2) only keeping terms in the vocabulary that occur in at least 1% of documents
    # (3) allowing both unigrams and bigrams in the vocabulary (use "ngram_range=(1,2)" to do this)
    vectorizerText = CountVectorizer(stop_words = 'english', min_df=.01, ngram_range=(1,2), tokenizer= pf.LemmaTokenizer() )
    #vectorizerNoLem = CountVectorizer(stop_words = 'english', min_df=.01, ngram_range=(1,2)) #no lemmatization
    
    # create a sparse BOW array from 'text' using vectorizer  
    X = vectorizerText.fit_transform(text)
    #X2 = vectorizerNoLem.fit_transform(text)
    
    print('Data shape for text: ', X.shape)
    # print('Data shape for text: ', X2.shape)
    
    #can comment out to not see the vocabularies
    print('Vocabulary for text: ', vectorizerText.get_feature_names())
    print('Count Vectorizer Vocab', vectorizerText.vocabulary_)

    return X, Y, vectorizerText

_, _, trueVectorizerText = getTrueCoronaVocabulary()
# Out:
# Extracting tokens from each review.....(can be slow for a large number of reviews)......
# there are 2 nan titles
# there are 3 nan text
# Data shape for text:  (586, 4677)
# Vocabulary for text:  ['1', '1 2', '1 metre', '1 trial', '10', '10 day', '10 percent', '100', '100 year', '1000', '100000', '11', '12', '12 18', '13', '14', '14 day', '15', '16', '17', '18', '18 month', '19', '1918', '2', '2 meter', '2 percent', '2 year', '20', '20 second', '200', '2000', '200000', '200000 people', '2000s', '2003', '2003 sars', '2009', '2012', '2014', '2015', '2016', '2017', '2018', '2019', '2019 novel', '2020', '2021', '21', '22', '23', '24', '24 hour', '25', '26', '27', '28', '28 day', '3', '30', '3000', '30000', '31', '33', '35', '36', '4', '40', '40 percent', '45', '48', '48 72', '48 hour', '5', '50', '50 million', '500', '5g', '6', '6 foot', '60', '60 alcohol', '60 percent', '600', '62', '65', '65 year', '7', '70', '72', '72 hour', '8', '80', '8000', '9', '90', '911', '95', '95 percent', '96', 'abdominal', 'abdominal pain', 'ability', 'able', 'able recover', 'able spread', 'abroad', 'absence', 'absolutely', 'academic', 'academy', 'academy science', 'accelerate', 'access', 'accessible', 'accidentally', 'according', 'according cdc', 'according center', 'according new', 'according report', 'according study', 'according world', 'account', 'accuracy', 'accurate', 'accurately', 'ace2', 'ace2 receptor', 'acetaminophen', 'ache', 'ache pain', 'achieve', 'acid', 'acknowledge', 'acknowledged', 'acquired', 'act', 'action', 'action taken', 'active', 'actively', 'activity', 'actor', 'actual', 'actually', 'actually make', 'acute', 'acute respiratory', 'adapted', 'add', 'added', 'adding', 'addition', 'additional', 'additionally', 'address', 'addressed', 'adequate', 'adhanom', 'adhanom ghebreyesus', 'administration', 'administration ha', 'administration s', 'admission', 'admitted', 'adopted', 'adult', 'adult people', 'advance', 'advanced', 'advantage', 'adverse', 'advice', 'advise', 'advised', 'adviser', 'advises', 'advisory', 'aerosol', 'affect', 'affect brain', 'affected', 'affected area', 'affecting', 'africa', 'age', 'age 2', 'age group', 'age underlying', 'aged', 'agency', 'agency epa', 'agent', 'aggressive', 'aggressively', 'ago', 'agree', 'agreed', 'agreement', 'ahead', 'aid', 'aim', 'aimed', 'air', 'air hour', 'airborne', 'airline', 'airport', 'airway', 'alarm', 'alarming', 'alcohol', 'alcohol covering', 'alert', 'alerted', 'alex', 'alive', 'allergy', 'allergy infectious', 'alliance', 'allow', 'allowed', 'allowing', 'allows', 'alongside', 'altered', 'alternative', 'america', 'american', 'amid', 'analysis', 'analyst', 'analyzed', 'analyzing', 'andersen', 'andrew', 'anecdotal', 'angiotensin', 'animal', 'animal host', 'animal human', 'animal including', 'animal market', 'animal specie', 'animal study', 'animal virus', 'animal wa', 'announced', 'answer', 'answer question', 'answered', 'anthony', 'anthony fauci', 'antibacterial', 'antibiotic', 'antibody', 'antibody blood', 'antibody body', 'antibody created', 'antibody help', 'antibody important', 'antibody test', 'antibody testing', 'antibody virus', 'antigen', 'antimalarial', 'antimicrobial', 'antimicrobial property', 'antiviral', 'antiviral drug', 'antiviral medication', 'antiviral treatment', 'anxiety', 'anxious', 'apart', 'app', 'apparent', 'apparently', 'appear', 'appear day', 'appeared', 'appears', 'appetite', 'appetite loss', 'applied', 'apply', 'appointment', 'approach', 'approach ha', 'appropriate', 'appropriately', 'approval', 'approved', 'approximately', 'april', 'arabia', 'area', 'aren', 'aren t', 'argued', 'argues', 'arise', 'arisen', 'arm', 'army', 'arose', 'array', 'arrival', 'arrive', 'arrived', 'arrives', 'arthritis', 'article', 'article published', 'asia', 'ask', 'asked', 'asking', 'aspect', 'ass', 'assessed', 'assessment', 'assistance', 'assistant', 'assistant professor', 'associate', 'associate professor', 'associated', 'associated symptom', 'association', 'assume', 'asthma', 'asymptomatic', 'asymptomatic case', 'attach', 'attack', 'attempt', 'attend', 'attention', 'australia', 'author', 'authority', 'autoimmune', 'autoimmune disease', 'availabilit ...
# Count Vectorizer Vocab {'stay': 3849, 'aware': 360, 'latest': 2265, 'information': 2105, 'outbreak': 2769, 'available': 346, 'website': 4589, 'national': 2610, 'local': 2350, 'public': 3175, 'health': 1832, 'authority': 342, 'people': 2851, 'infected': 2066, 'experience': 1454, 'mild': 2526, 'illness': 1988, 'recover': 3265, 'severe': 3642, 'care': 532, 'protect': 3139, 'doing': 1244, 'following': 1603, 'wash': 4546, 'hand': 1787, 'frequently': 1632, 'regularly': 3290, 'thoroughly': 4109, 'clean': 684, 'rub': 3452, 'soap': 3747, 'washing': 4550, 'water': 4560, 'using': 4343, 'kill': 2213, 'virus': 4437, 'maintain': 2402, 'social': 3749, 'distancing': 1210, '1': 0, 'metre': 2517, '3': 58, 'foot': 1608, 'distance': 1206, 'coughing': 953, 'sneezing': 3743, 'cough': 945, 'sneeze': 3741, 'spray': 3802, 'small': 3732, 'liquid': 2334, 'droplet': 1278, 'nose': 2671, 'mouth': 2586, 'contain': 846, 'close': 701, 'breathe': 486, 'including': 2037, 'person': 2922, 'ha': 1753, 'disease': 1167, 'avoid': 353, 'touching': 4160, 'eye': 1490, 'touch': 4153, 'surface': 3954, 'pick': 2958, 'contaminated': 856, 'transfer': 4184, 'enter': 1377, 'body': 462, 'make': 2410, 'sick': 3686, 'practice': 3030, 'respiratory': 3371, 'hygiene': 1970, 'sure': 3953, 'follow': 1598, 'good': 1712, 'mean': 2465, 'covering': 977, 'elbow': 1336, 'tissue': 4134, 'dispose': 1204, 'used': 4337, 'immediately': 1997, 'spread': 3803, 'cold': 724, 'flu': 1584, 'fever': 1547, 'difficulty': 1147, 'breathing': 488, 'seek': 3602, 'medical': 2477, 'early': 1299, 'home': 1909, 'feel': 1541, 'unwell': 4319, 'attention': 339, 'advance': 169, 'direction': 1154, 'date': 1022, 'situation': 3718, 'area': 297, 'calling': 515, 'allow': 221, 'provider': 3166, 'quickly': 3204, 'direct': 1151, 'right': 3414, 'facility': 1502, 'help': 1870, 'prevent': 3070, 'infection': 2082, 'informed': 2107, 'advice': 173, 'given': 1696, 'healthcare': 1854, 'development': 1114, 'spreading': 3820, 'best': 420, 'placed': 2967, 'advise': 174, 'protective': 3151, 'measure': 2472, 'new': 2645, 'coronavirus': 892, 'local public': 2354, 'public health': 3176, 'health authority': 1834, 'people infected': 2875, 'mild illness': 2528, 'wash hand': 4547, 'hand frequently': 1790, 'clean hand': 687, 'hand hand': 1791, 'hand rub': 1793, 'rub wash': 3453, 'wash soap': 4548, 'washing hand': 4551, 'hand soap': 1796, 'soap water': 3748, 'using hand': 4344, 'kill virus': 2215, 'virus hand': 4457, 'maintain social': 2404, 'social distancing': 3750, '1 metre': 2, 'foot distance': 1611, 'coughing sneezing': 954, 'cough sneeze': 950, 'nose mouth': 2674, 'contain virus': 848, 'including virus': 2038, 'virus person': 4476, 'avoid touching': 357, 'touching eye': 4162, 'eye nose': 1492, 'touch surface': 4157, 'virus enter': 4455, 'make sure': 2415, 'mouth nose': 2587, 'tissue cough': 4135, 'used tissue': 4339, 'spread virus': 3817, 'protect people': 3144, 'people virus': 2907, 'cold flu': 725, 'fever cough': 1549, 'cough difficulty': 946, 'difficulty breathing': 1148, 'seek medical': 3603, 'medical care': 2480, 'stay home': 3851, 'medical attention': 2479, 'local health': 2353, 'local authority': 2351, 'health care': 1835, 'care provider': 536, 'health facility': 1841, 'help prevent': 1877, 'prevent spread': 3074, 'follow advice': 1599, 'healthcare provider': 1855, 'protective measure': 3153, 'new coronavirus': 2647, 'catch': 566, 'matter': 2461, 'hot': 1935, 'weather': 4587, 'country': 960, 'reported': 3333, 'case': 549, 'sun': 3940, 'temperature': 4063, 'higher': 1894, 'degree': 1066, 'doe': 1232, 'hot weather': 1936, 'reported case': 3334, 'eye mouth': 1491, 'temperature higher': 4064, 'doe prevent': 1238, 'prevent coronavirus': 3071, 'coronavirus disease': 900, 'eliminate': 1339, 'treat': 4210, 'symptom': 3983, 'telephone': 4059, 'patient': 2831, 'thanks': 4094, 'supportive': 3951, 'catching': 567, 'life': 2302, 'people catch': 2855, 'eliminate virus': 1340, 'virus body': 4443, 'treat symptom': 4215, 'symptom cough': 3990, 'coug ...

# %%
true_counter = sum(trueVectorizerText.vocabulary_.values())

true_and_fake_counter = true_counter + fake_counter

top_10_fake_percentage_of_fake = np.array(top_10_fake)[:,1]
top_10_fake_percentage_of_total = np.array(top_10_fake)[:,1]

top_10_fake_percentage_of_fake = np.array(top_10_fake_percentage_of_fake, dtype=np.float64)
top_10_fake_percentage_of_total = np.array(top_10_fake_percentage_of_total, dtype=np.float64)


top_10_fake_percentage_of_fake = top_10_fake_percentage_of_fake / fake_counter
top_10_fake_percentage_of_total = top_10_fake_percentage_of_total / true_and_fake_counter

# %% [markdown]
# ### Top 10 Words in False Articles (as percentage of total number of words in fake articles)

# %%
import matplotlib.pyplot as plt

# %%
top_10_fake_words = np.array(top_10_fake)[:,0]

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 2, 2])
ax.bar(top_10_fake_words, top_10_fake_percentage_of_fake)
plt.show()

# %% [markdown]
# ### Top 10 Words in False Articles (as percentage of total number of words in fake articles + true articles)

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 2, 2])
ax.bar(top_10_fake_words, top_10_fake_percentage_of_total)
plt.show()

# %% [markdown]
# ### Top 10 Words in True Articles

# %%
top_10_true = sorted(trueVectorizerText.vocabulary_.items(), key=(lambda x : -x[1]))[:10]
print(top_10_true)
# Out:
# [('zoonotic', 4676), ('zika', 4675), ('zero', 4674), ('youtube', 4673), ('younger people', 4672), ('younger', 4671), ('young healthy', 4670), ('young child', 4669), ('young adult', 4668), ('young', 4667)]

# %% [markdown]
# ### Top 10 Words in True Articles (as percentage of total number of words in True articles)

# %%
top_10_true_percentage_of_true = np.array(top_10_true)[:,1]
top_10_true_percentage_of_total = np.array(top_10_true)[:,1]

top_10_true_percentage_of_true = np.array(top_10_true_percentage_of_true, dtype=np.float64)
top_10_true_percentage_of_total = np.array(top_10_true_percentage_of_total, dtype=np.float64)


top_10_true_percentage_of_true = top_10_true_percentage_of_true / true_counter
top_10_true_percentage_of_total = top_10_true_percentage_of_total / true_and_fake_counter

top_10_true_words = np.array(top_10_true)[:,0]

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 2, 2])
ax.bar(top_10_true_words, top_10_true_percentage_of_true)
plt.show()

# %% [markdown]
# ### Top 10 Words in True Articles (as percentage of total number of words in fake articles + true articles)

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 2, 2])
ax.bar(top_10_true_words, top_10_true_percentage_of_total)
plt.show()

# %% [markdown]
# ### Word with most frequency

# %%
sorted(vectorizerText.vocabulary_.items(), key=(lambda x : -x[1]))[0]
# Out:
# ('zoonotic', 4650)

# %% [markdown]
# ### Word with least frequency

# %%
sorted(vectorizerText.vocabulary_.items(), key=(lambda x : x[1]))[1]
# Out:
# ('1 2', 1)

# %% [markdown]
# ### Top 10 words that appear in true articles but not in false articles

# %%
words_in_fake = set(fakeVectorizerText.vocabulary_.keys())
words_in_true = set(trueVectorizerText.vocabulary_.keys())
words_in_true_not_in_fake = words_in_true - words_in_fake

words_in_true_not_in_fake_list = []

for word, count in trueVectorizerText.vocabulary_.items():
    if word in words_in_true_not_in_fake:
        words_in_true_not_in_fake_list.append((word, count))

print(sorted(words_in_true_not_in_fake_list, key=(lambda x : -x[1]))[:10])
# Out:
# [('younger people', 4672), ('younger', 4671), ('young healthy', 4670), ('young child', 4669), ('young adult', 4668), ('york state', 4665), ('year older', 4660), ('yale university', 4657), ('yale', 4656), ('worsening', 4644)]

# %% [markdown]
# ### Top 10 words that appear in false articles but not in true articles

# %%
words_in_fake_not_in_true = words_in_fake - words_in_true

words_in_fake_not_in_true_list = []

for word, count in fakeVectorizerText.vocabulary_.items():
    if word in words_in_fake_not_in_true:
        words_in_fake_not_in_true_list.append((word, count))
        
print(sorted(words_in_fake_not_in_true_list, key=(lambda x : -x[1]))[:10])
# Out:
# [('zone', 6204), ('zinc', 6203), ('zhou', 6201), ('zhengli', 6200), ('zerohedge', 6199), ('zero nml', 6198), ('zero hedge', 6197), ('zero death', 6196), ('zelenko', 6194), ('zaki using', 6193)]
